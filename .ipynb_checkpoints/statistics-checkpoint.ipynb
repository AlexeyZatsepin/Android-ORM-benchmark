# %%
import matplotlib.pyplot as pp
import pandas as pd
import seaborn
import itertools
# %matplotlib inline

# %%
level = ['simple','complex','balanced']
action = ['read','write','update','delete']

table_titles = [ x + " "+ y  for x in level for y in action]
print table_titles
# Out:
# ['simple read', 'simple write', 'simple update', 'simple delete', 'complex read', 'complex write', 'complex update', 'complex delete', 'balanced read', 'balanced write', 'balanced update', 'balanced delete']

# %%
result_table = pd.read_csv('result.csv',names=['name']+table_titles)
result_table
# Out:
#         name  simple read  simple write  simple update  simple delete  \
# 0    ORMLite          151           666            122            105
# 1   SugarORM          245           842            252            152
# 2     DBFlow           97           757            459            186
# 3    Freezer          248          5430            240           4797
# 4    Requery           87          1501            147            129
# 5     SQLite           96            17             57             94
# 6  Sprinkles         5898           339           5138            644
# 7   GreenDao           64            24             76             60
# 8       Room           98            20             92             82
#
#    complex read  complex write  complex update  complex delete  balanced read  \
# 0           445           3836             857             811           1563
# 1          1402           4129            1467            1003           2204
# 2           360           3534            3124            1044           1129
# 3          1337          78982            2221           22104           3255
# 4           461           8057             861             802           1368
# 5           384            242             161             244           1138
# 6         26361           1509           29840            2602          33267
# 7           355            127             391             210            622
# 8           454             93             359             269           1295
#
#    balanced write  balanced update  balanced delete
# 0            3426              724              728
# 1            4397             1702             1197
# 2            4653             5204             1268
# 3          134942             1887            29515
# 4            8002              886              763
# 5             259              185              292
# 6            1683            33985             2865
# 7             127              362              278
# 8             101              417              301

# %%
colors=['#0D47A1','r','g','y','w','k','c','m','#1E88E5']

rows = len(result_table.index)

def benchmark_plot(title, data_titles, maximum=0):
    local_max = maximum
    pp.figure(figsize=(12,2.5))
    pp.title(title)
    for i in range(rows):
        row = result_table.iloc[i]
        data = [row[k] for k in data_titles]
        if maximum == 0 and local_max<max(data):
            local_max = max(data)
        pp.bar([len(result_table.index)*j+i for j in range(4)],data, label=row['name'], color=colors[i])

    pp.xticks([len(result_table.index)*j+4 for j in range(4)],[k.split()[1] for k in data_titles])
    pp.legend()
    maximum = local_max
    pp.axis((0,rows*4,0,maximum))
    #pp.xlabel('libs')
    pp.ylabel('ms')

# %%
benchmark_plot('Simple ORM Benchmark',table_titles[:4])

# %%
benchmark_plot('Complex ORM Benchmark',table_titles[4:8],20000)

# %%
benchmark_plot('Balanced ORM Benchmark',table_titles[8:12],20000)

# %%
for item in table_titles:
    print(result_table.set_index([item]).sort_index()['name'])
# Out:
# simple read
# 64       GreenDao
# 87        Requery
# 96         SQLite
# 97         DBFlow
# 98           Room
# 151       ORMLite
# 245      SugarORM
# 248       Freezer
# 5898    Sprinkles
# Name: name, dtype: object
# simple write
# 17         SQLite
# 20           Room
# 24       GreenDao
# 339     Sprinkles
# 666       ORMLite
# 757        DBFlow
# 842      SugarORM
# 1501      Requery
# 5430      Freezer
# Name: name, dtype: object
# simple update
# 57         SQLite
# 76       GreenDao
# 92           Room
# 122       ORMLite
# 147       Requery
# 240       Freezer
# 252      SugarORM
# 459        DBFlow
# 5138    Sprinkles
# Name: name, dtype: object
# simple delete
# 60       GreenDao
# 82           Room
# 94         SQLite
# 105       ORMLite
# 129       Requery
# 152      SugarORM
# 186        DBFlow
# 644     Sprinkles
# 4797      Freezer
# Name: name, dtype: object
# complex read
# 355       GreenDao
# 360         DBFlow
# 384         SQLite
# 445        ORMLite
# 454           Room
# 461        Requery
# 1337       Freezer
# 1402      SugarORM
# 26361    Sprinkles
# Name: name, dtype: object
# complex write
# 93            Room
# 127       GreenDao
# 242         SQLite
# 1509     Sprinkles
# 3534        DBFlow
# 3836       ORMLite
# 4129      SugarORM
# 8057       Requery
# 78982      Freezer
# Name: name, dtype: object
# complex update
# 161         SQLite
# 359           Room
# 391       GreenDao
# 857        ORMLite
# 861        Requery
# 1467      SugarORM
# 2221       Freezer
# 3124        DBFlow
# 29840    Sprinkles
# Name: name, dtype: object
# complex delete
# 210       GreenDao
# 244         SQLite
# 269           Room
# 802        Requery
# 811        ORMLite
# 1003      SugarORM
# 1044        DBFlow
# 2602     Sprinkles
# 22104      Freezer
# Name: name, dtype: object
# balanced read
# 622       GreenDao
# 1129        DBFlow
# 1138        SQLite
# 1295          Room
# 1368       Requery
# 1563       ORMLite
# 2204      SugarORM
# 3255       Freezer
# 33267    Sprinkles
# Name: name, dtype: object
# balanced write
# 101            Room
# 127        GreenDao
# 259          SQLite
# 1683      Sprinkles
# 3426        ORMLite
# 4397       SugarORM
# 4653         DBFlow
# 8002        Requery
# 134942      Freezer
# Name: name, dtype: object
# balanced update
# 185         SQLite
# 362       GreenDao
# 417           Room
# 724        ORMLite
# 886        Requery
# 1702      SugarORM
# 1887       Freezer
# 5204        DBFlow
# 33985    Sprinkles
# Name: name, dtype: object
# balanced delete
# 278       GreenDao
# 292         SQLite
# 301           Room
# 728        ORMLite
# 763        Requery
# 1197      SugarORM
# 1268        DBFlow
# 2865     Sprinkles
# 29515      Freezer
# Name: name, dtype: object

# %%
result_table.sort_values(table_titles[0])
# Out:
#         name  simple read  simple write  simple update  simple delete  \
# 7   GreenDao           64            24             76             60
# 4    Requery           87          1501            147            129
# 5     SQLite           96            17             57             94
# 2     DBFlow           97           757            459            186
# 8       Room           98            20             92             82
# 0    ORMLite          151           666            122            105
# 1   SugarORM          245           842            252            152
# 3    Freezer          248          5430            240           4797
# 6  Sprinkles         5898           339           5138            644
#
#    complex read  complex write  complex update  complex delete  balanced read  \
# 7           355            127             391             210            622
# 4           461           8057             861             802           1368
# 5           384            242             161             244           1138
# 2           360           3534            3124            1044           1129
# 8           454             93             359             269           1295
# 0           445           3836             857             811           1563
# 1          1402           4129            1467            1003           2204
# 3          1337          78982            2221           22104           3255
# 6         26361           1509           29840            2602          33267
#
#    balanced write  balanced update  balanced delete
# 7             127              362              278
# 4            8002              886              763
# 5             259              185              292
# 2            4653             5204             1268
# 8             101              417              301
# 0            3426              724              728
# 1            4397             1702             1197
# 3          134942             1887            29515
# 6            1683            33985             2865

# %%
result_table.sort_values(table_titles[1])
# Out:
#         name  simple read  simple write  simple update  simple delete  \
# 5     SQLite           96            17             57             94
# 7   GreenDao           64            24             76             60
# 8       Room           98            20             92             82
# 0    ORMLite          151           666            122            105
# 4    Requery           87          1501            147            129
# 3    Freezer          248          5430            240           4797
# 1   SugarORM          245           842            252            152
# 2     DBFlow           97           757            459            186
# 6  Sprinkles         5898           339           5138            644
#
#    complex read  complex write  complex update  complex delete  balanced read  \
# 5           384            242             161             244           1138
# 7           355            127             391             210            622
# 8           454             93             359             269           1295
# 0           445           3836             857             811           1563
# 4           461           8057             861             802           1368
# 3          1337          78982            2221           22104           3255
# 1          1402           4129            1467            1003           2204
# 2           360           3534            3124            1044           1129
# 6         26361           1509           29840            2602          33267
#
#    balanced write  balanced update  balanced delete
# 5             259              185              292
# 7             127              362              278
# 8             101              417              301
# 0            3426              724              728
# 4            8002              886              763
# 3          134942             1887            29515
# 1            4397             1702             1197
# 2            4653             5204             1268
# 6            1683            33985             2865
